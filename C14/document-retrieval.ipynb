# %% [markdown]
# # Document retrieval from wikipedia data

# %% [markdown]
# ## Fire up GraphLab Create

# %%
import graphlab

# %% [markdown]
# # Load some text data - from wikipedia, pages on people

# %%
people = graphlab.SFrame('people_wiki.gl/')
# Out:
# This non-commercial license of GraphLab Create is assigned to ykushla@gmail.com and will expire on May 25, 2017. For commercial licensing options, visit https://dato.com/buy/.
# [INFO] graphlab.cython.cy_server: GraphLab Create v1.10.1 started. Logging: C:\Users\ykushla\AppData\Local\Temp\graphlab_server_1466343432.log.0

# %% [markdown]
# Data contains:  link to wikipedia article, name of person, text of article.

# %%
people.head()
# Out:
# Columns:
# 	URI	str
# 	name	str
# 	text	str
#
# Rows: 10
#
# Data:
# +-------------------------------+---------------------+
# |              URI              |         name        |
# +-------------------------------+---------------------+
# | <http://dbpedia.org/resour... |    Digby Morrell    |
# | <http://dbpedia.org/resour... |    Alfred J. Lewy   |
# | <http://dbpedia.org/resour... |    Harpdog Brown    |
# | <http://dbpedia.org/resour... | Franz Rottensteiner |
# | <http://dbpedia.org/resour... |        G-Enka       |
# | <http://dbpedia.org/resour... |    Sam Henderson    |
# | <http://dbpedia.org/resour... |    Aaron LaCrate    |
# | <http://dbpedia.org/resour... |   Trevor Ferguson   |
# | <http://dbpedia.org/resour... |     Grant Nelson    |
# | <http://dbpedia.org/resour... |     Cathy Caruth    |
# +-------------------------------+---------------------+
# +-------------------------------+
# |              text             |
# +-------------------------------+
# ...

# %%
len(people)
# Out:
# 59071

# %% [markdown]
# # Explore the dataset and checkout the text it contains
#
# ## Exploring the entry for president Obama

# %%
obama = people[people['name'] == 'Barack Obama']

# %%
obama
# Out:
# Columns:
# 	URI	str
# 	name	str
# 	text	str
#
# Rows: Unknown
#
# Data:
# +-------------------------------+--------------+-------------------------------+
# |              URI              |     name     |              text             |
# +-------------------------------+--------------+-------------------------------+
# | <http://dbpedia.org/resour... | Barack Obama | barack hussein obama ii br... |
# +-------------------------------+--------------+-------------------------------+
# [? rows x 3 columns]
# Note: Only the head of the SFrame is printed. This SFrame is lazily evaluated.
# You can use sf.materialize() to force materialization.

# %%
obama['text']
# Out:
# dtype: str
# Rows: ?
# ...

# %% [markdown]
# ## Exploring the entry for actor George Clooney

# %%
clooney = people[people['name'] == 'George Clooney']
clooney['text']
# Out:
# dtype: str
# Rows: ?
# ...

# %% [markdown]
# # Get the word counts for Obama article

# %%
obama['word_count'] = graphlab.text_analytics.count_words(obama['text'])

# %%
print(obama['word_count'])
# Out:
# [{'graduate': 1, 'other': 1, 'obamacare': 1, 'during': 2, 'represent': 1, 'raise': 1, 'states': 3, 'not': 1, 'act': 8, 'continued': 1, 'ii': 1, 'limit': 1, '20': 2, 'initiatives': 1, 'republican': 2, 'arms': 1, 'libya': 1, 'president': 4, 'mitt': 1, 'two': 1, 'barack': 1, '1961': 1, 'iraq': 4, 'national': 2, 'court': 1, 'sought': 1, 'general': 1, 'he': 7, 'defeating': 1, 'job': 1, 'law': 6, 'bm': 1, 'representing': 1, 'nobel': 1, 'hold': 1, 'start': 1, 'gains': 1, '8': 1, 'inaugurated': 1, 'reinvestment': 1, 'on': 2, 'state': 1, '2009': 3, 'domestic': 2, 'senate': 3, 'john': 1, 'tax': 1, 'full': 1, 'operation': 1, 'islamic': 1, 'rights': 1, 'osama': 1, 'march': 1, 'marriage': 1, 'cuba': 1, 'unconstitutional': 1, 'death': 1, 'laureateduring': 1, 'representatives': 2, 'hook': 1, 'january': 3, 'whether': 1, 'nations': 1, '2004': 3, 'patient': 1, 'reform': 1, '4': 1, 'term': 3, 'equality': 1, 'dont': 2, 'nine': 1, 'called': 1, 'presidential': 2, 'after': 4, 'tell': 1, 'sandy': 1, 'recove
# ...

# %% [markdown]
# ## Sort the word counts for the Obama article

# %% [markdown]
# ### Turning dictonary of word counts into a table

# %%
obama_word_count_table = obama[['word_count']].stack('word_count', new_column_name = ['word','count'])

# %% [markdown]
# ### Sorting the word counts to show most common words at the top

# %%
obama_word_count_table.head()
# Out:
# Columns:
# 	word	str
# 	count	int
#
# Rows: 10
#
# Data:
# +------------------+-------+
# |       word       | count |
# +------------------+-------+
# |    normalize     |   1   |
# |      sought      |   1   |
# |      combat      |   1   |
# |    continued     |   1   |
# | unconstitutional |   1   |
# |        8         |   1   |
# |   californias    |   1   |
# |       1996       |   1   |
# |     marriage     |   1   |
# |     defense      |   1   |
# +------------------+-------+
# [10 rows x 2 columns]

# %%
obama_word_count_table.sort('count',ascending=False)
# Out:
# Columns:
# 	word	str
# 	count	int
#
# Rows: 273
#
# Data:
# +-------+-------+
# |  word | count |
# +-------+-------+
# |  the  |   40  |
# |   in  |   30  |
# |  and  |   21  |
# |   of  |   18  |
# |   to  |   14  |
# |  his  |   11  |
# | obama |   9   |
# |  act  |   8   |
# |   a   |   7   |
# |   he  |   7   |
# +-------+-------+
# [273 rows x 2 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %% [markdown]
# Most common words include uninformative words like "the", "in", "and",...

# %% [markdown]
# # Compute TF-IDF for the corpus
#
# To give more weight to informative words, we weigh them by their TF-IDF scores.

# %%
people['word_count'] = graphlab.text_analytics.count_words(people['text'])
people.head()
# Out:
# Columns:
# 	URI	str
# 	name	str
# 	text	str
# 	word_count	dict
#
# Rows: 10
#
# Data:
# +-------------------------------+---------------------+
# |              URI              |         name        |
# +-------------------------------+---------------------+
# | <http://dbpedia.org/resour... |    Digby Morrell    |
# | <http://dbpedia.org/resour... |    Alfred J. Lewy   |
# | <http://dbpedia.org/resour... |    Harpdog Brown    |
# | <http://dbpedia.org/resour... | Franz Rottensteiner |
# | <http://dbpedia.org/resour... |        G-Enka       |
# | <http://dbpedia.org/resour... |    Sam Henderson    |
# | <http://dbpedia.org/resour... |    Aaron LaCrate    |
# | <http://dbpedia.org/resour... |   Trevor Ferguson   |
# | <http://dbpedia.org/resour... |     Grant Nelson    |
# | <http://dbpedia.org/resour... |     Cathy Caruth    |
# +-------------------------------+---------------------+
# +-------------------------------+-------------------------------+
# ...

# %%
tfidf = graphlab.text_analytics.tf_idf(people['word_count'])

# Earlier versions of GraphLab Create returned an SFrame rather than a single SArray
# This notebook was created using Graphlab Create version 1.7.1
# if graphlab.version <= '1.6.1':
#    tfidf = tfidf['docs']

tfidf
# Out:
# dtype: dict
# Rows: 59071
# ...

# %%
people['tfidf'] = tfidf

# %% [markdown]
# ## Examine the TF-IDF for the Obama article

# %%
obama = people[people['name'] == 'Barack Obama']

# %%
clooney = people[people["name"] == "George Clooney"]

# %%
obama[['tfidf']].stack('tfidf',new_column_name=['word','tfidf']).sort('tfidf',ascending=False)
# Out:
# Columns:
# 	word	str
# 	tfidf	float
#
# Rows: 273
#
# Data:
# +-------------+--------------------+
# |     word    |       tfidf        |
# +-------------+--------------------+
# |    obama    |  43.2956530720749  |
# |     act     | 27.67822262297991  |
# |     iraq    | 17.747378587965535 |
# |   control   | 14.887060845181308 |
# |     law     | 14.722935761763422 |
# |   ordered   | 14.533373950913514 |
# |   military  | 13.115932778499415 |
# | involvement | 12.784385241175055 |
# |   response  | 12.784385241175055 |
# |  democratic | 12.410688697332166 |
# +-------------+--------------------+
# [273 rows x 2 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %% [markdown]
# Words with highest TF-IDF are much more informative.

# %% [markdown]
# # Manually compute distances between a few people
#
# Let's manually compare the distances between the articles for a few famous people.

# %%
clinton = people[people['name'] == 'Bill Clinton']

# %%
beckham = people[people['name'] == 'David Beckham']

# %% [markdown]
# ## Is Obama closer to Clinton than to Beckham?
#
# We will use cosine distance, which is given by
#
# (1-cosine_similarity)
#
# and find that the article about president Obama is closer to the one about former president Clinton than that of footballer David Beckham.

# %%
graphlab.distances.cosine(obama['tfidf'][0],clinton['tfidf'][0])
# Out:
# 0.8339854936884277

# %%
graphlab.distances.cosine(obama['tfidf'][0],beckham['tfidf'][0])
# Out:
# 0.9791305844747478

# %% [markdown]
# # Build a nearest neighbor model for document retrieval
#
# We now create a nearest-neighbors model and apply it to document retrieval.

# %%
knn_model = graphlab.nearest_neighbors.create(people,features=['tfidf'],label='name')
# Out:
# Starting brute force nearest neighbors model training.

# %% [markdown]
# # Applying the nearest-neighbors model for retrieval

# %% [markdown]
# ## Who is closest to Obama?

# %%
knn_model.query(obama)
# Out:
# Starting pairwise querying.
# +--------------+---------+-------------+--------------+
# | Query points | # Pairs | % Complete. | Elapsed Time |
# +--------------+---------+-------------+--------------+
# | 0            | 1       | 0.00169288  | 11.029ms     |
# | Done         |         | 100         | 340.88ms     |
# +--------------+---------+-------------+--------------+
# Columns:
# 	query_label	int
# 	reference_label	str
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+-----------------+--------------------+------+
# | query_label | reference_label |      distance      | rank |
# +-------------+-----------------+--------------------+------+
# |      0      |   Barack Obama  |        0.0         |  1   |
# |      0      |    Joe Biden    | 0.7941176470588236 |  2   |
# |      0      |  Joe Lieberman  | 0.7946859903381642 |  3   |
# |      0      |   Kelly Ayotte  | 0.8119891008174387 |  4   |
# |      0      |   Bill Clinton  | 0.8138528138528138 |  5   |
# ...

# %% [markdown]
# As we can see, president Obama's article is closest to the one about his vice-president Biden, and those of other politicians.

# %% [markdown]
# ## Other examples of document retrieval

# %%
swift = people[people['name'] == 'Taylor Swift']

# %%
knn_model.query(swift)
# Out:
# Starting pairwise querying.
# +--------------+---------+-------------+--------------+
# | Query points | # Pairs | % Complete. | Elapsed Time |
# +--------------+---------+-------------+--------------+
# | 0            | 1       | 0.00169288  | 9.528ms      |
# | Done         |         | 100         | 297.794ms    |
# +--------------+---------+-------------+--------------+
# Columns:
# 	query_label	int
# 	reference_label	str
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+------------------+--------------------+------+
# | query_label | reference_label  |      distance      | rank |
# +-------------+------------------+--------------------+------+
# |      0      |   Taylor Swift   |        0.0         |  1   |
# |      0      | Carrie Underwood | 0.7623188405797101 |  2   |
# |      0      |   Alicia Keys    | 0.7647058823529411 |  3   |
# |      0      |  Jordin Sparks   | 0.7696335078534031 |  4   |
# ...

# %%
jolie = people[people['name'] == 'Angelina Jolie']

# %%
knn_model.query(jolie)
# Out:
# Starting pairwise querying.
# +--------------+---------+-------------+--------------+
# | Query points | # Pairs | % Complete. | Elapsed Time |
# +--------------+---------+-------------+--------------+
# | 0            | 1       | 0.00169288  | 18.047ms     |
# | Done         |         | 100         | 356.948ms    |
# +--------------+---------+-------------+--------------+
# Columns:
# 	query_label	int
# 	reference_label	str
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+--------------------+--------------------+------+
# | query_label |  reference_label   |      distance      | rank |
# +-------------+--------------------+--------------------+------+
# |      0      |   Angelina Jolie   |        0.0         |  1   |
# |      0      |     Brad Pitt      | 0.7840236686390533 |  2   |
# |      0      |   Julianne Moore   | 0.7958579881656804 |  3   |
# |      0      | Billy Bob Thornton |  0.80306905370844  |  4   |
# ...

# %%
arnold = people[people['name'] == 'Arnold Schwarzenegger']

# %%
knn_model.query(arnold)
# Out:
# Starting pairwise querying.
# +--------------+---------+-------------+--------------+
# | Query points | # Pairs | % Complete. | Elapsed Time |
# +--------------+---------+-------------+--------------+
# | 0            | 1       | 0.00169288  | 16.043ms     |
# | Done         |         | 100         | 340.906ms    |
# +--------------+---------+-------------+--------------+
# Columns:
# 	query_label	int
# 	reference_label	str
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+-----------------------+--------------------+------+
# | query_label |    reference_label    |      distance      | rank |
# +-------------+-----------------------+--------------------+------+
# |      0      | Arnold Schwarzenegger |        0.0         |  1   |
# |      0      |     Jesse Ventura     | 0.8189189189189189 |  2   |
# |      0      |     John Kitzhaber    | 0.8246153846153846 |  3   |
# |      0      |     Lincoln Chafee    | 0.8338762214983714 |  4   |
# ...

# %% [markdown]
# # C14 - Assignment

# %% [markdown]
# # Task #1

# %%
eltonjohn = people[people["name"] == "Elton John"]

# %%
eltonjohn
# Out:
# Columns:
# 	URI	str
# 	name	str
# 	text	str
# 	word_count	dict
# 	tfidf	dict
#
# Rows: Unknown
#
# Data:
# +-------------------------------+------------+-------------------------------+
# |              URI              |    name    |              text             |
# +-------------------------------+------------+-------------------------------+
# | <http://dbpedia.org/resour... | Elton John | sir elton hercules john cb... |
# +-------------------------------+------------+-------------------------------+
# +-------------------------------+-------------------------------+
# |           word_count          |             tfidf             |
# +-------------------------------+-------------------------------+
# | {'continues': 1, 'involved... | {'continues': 3.3444509863... |
# +-------------------------------+-------------------------------+
# [? rows x 5 columns]
# Note: Only the head of the SFrame is printed. This SFrame is lazily evaluated.
# ...

# %%
sorted(eltonjohn["word_count"][0].items(), key=lambda x: x[1], reverse=True)[0:3]
# Out:
# [('the', 27), ('in', 18), ('and', 15)]

# %%
sorted(eltonjohn["tfidf"][0].items(), key=lambda x: x[1], reverse=True)[0:3]
# Out:
# [('furnish', 18.38947183999428),
#  ('elton', 17.482320270031995),
#  ('billboard', 17.30368095754203)]

# %% [markdown]
# # Task #2

# %%
vbeckham = people[people["name"] == "Victoria Beckham"]

# %%
graphlab.distances.cosine(eltonjohn["tfidf"][0], vbeckham["tfidf"][0])
# Out:
# 0.9567006376655429

# %%
paul = people[people["name"] == "Paul McCartney"]

# %%
graphlab.distances.cosine(eltonjohn["tfidf"][0], paul["tfidf"][0])
# Out:
# 0.825031002922178

# %% [markdown]
# # Task #3

# %%
model_wc = graphlab.nearest_neighbors.create(people, features=['word_count'], label='name', distance="cosine")
model_tfidf = graphlab.nearest_neighbors.create(people, features=['tfidf'], label='name', distance="cosine")
# Out:
# Starting brute force nearest neighbors model training.
# Starting brute force nearest neighbors model training.

# %%
model_wc.query(eltonjohn)
# Out:
# Starting pairwise querying.
# +--------------+---------+-------------+--------------+
# | Query points | # Pairs | % Complete. | Elapsed Time |
# +--------------+---------+-------------+--------------+
# | 0            | 1       | 0.00169288  | 7.019ms      |
# | Done         |         | 100         | 321.496ms    |
# +--------------+---------+-------------+--------------+
# Columns:
# 	query_label	int
# 	reference_label	str
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+-------------------+-----------------------+------+
# | query_label |  reference_label  |        distance       | rank |
# +-------------+-------------------+-----------------------+------+
# |      0      |     Elton John    | 2.220446049250313e-16 |  1   |
# |      0      |   Cliff Richard   |  0.16142415258967036  |  2   |
# |      0      |   Sandro Petrone  |  0.16822542751041114  |  3   |
# |      0      |    Rod Stewart    |  0.16832716558706107  |  4   |
# ...

# %%
model_tfidf.query(eltonjohn)
# Out:
# Starting pairwise querying.
# +--------------+---------+-------------+--------------+
# | Query points | # Pairs | % Complete. | Elapsed Time |
# +--------------+---------+-------------+--------------+
# | 0            | 1       | 0.00169288  | 9.022ms      |
# | Done         |         | 100         | 314.837ms    |
# +--------------+---------+-------------+--------------+
# Columns:
# 	query_label	int
# 	reference_label	str
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+------------------+------------------------+------+
# | query_label | reference_label  |        distance        | rank |
# +-------------+------------------+------------------------+------+
# |      0      |    Elton John    | -2.220446049250313e-16 |  1   |
# |      0      |   Rod Stewart    |   0.7172196678927374   |  2   |
# |      0      |  George Michael  |   0.7476009989692848   |  3   |
# |      0      | Sting (musician) |   0.7476719544306141   |  4   |
# ...

# %%
model_wc.query(vbeckham)
# Out:
# Starting pairwise querying.
# +--------------+---------+-------------+--------------+
# | Query points | # Pairs | % Complete. | Elapsed Time |
# +--------------+---------+-------------+--------------+
# | 0            | 1       | 0.00169288  | 8.021ms      |
# | Done         |         | 100         | 287.764ms    |
# +--------------+---------+-------------+--------------+
# Columns:
# 	query_label	int
# 	reference_label	str
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+--------------------------+------------------------+------+
# | query_label |     reference_label      |        distance        | rank |
# +-------------+--------------------------+------------------------+------+
# |      0      |     Victoria Beckham     | -2.220446049250313e-16 |  1   |
# |      0      | Mary Fitzgerald (artist) |  0.20730703611504997   |  2   |
# |      0      |      Adrienne Corri      |  0.21450978278754795   |  3   |
# ...

# %%
model_tfidf.query(vbeckham)
# Out:
# Starting pairwise querying.
# +--------------+---------+-------------+--------------+
# | Query points | # Pairs | % Complete. | Elapsed Time |
# +--------------+---------+-------------+--------------+
# | 0            | 1       | 0.00169288  | 9.024ms      |
# | Done         |         | 100         | 318.848ms    |
# +--------------+---------+-------------+--------------+
# Columns:
# 	query_label	int
# 	reference_label	str
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+---------------------+------------------------+------+
# | query_label |   reference_label   |        distance        | rank |
# +-------------+---------------------+------------------------+------+
# |      0      |   Victoria Beckham  | 1.1102230246251565e-16 |  1   |
# |      0      |    David Beckham    |   0.5481696102632145   |  2   |
# |      0      | Stephen Dow Beckham |   0.7849867068283364   |  3   |
# |      0      |        Mel B        |   0.8095855234085036   |  4   |
# ...
